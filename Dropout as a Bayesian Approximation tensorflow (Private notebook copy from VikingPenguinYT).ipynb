# %% [markdown]
# # Dropout as a Bayesian Approximation tensorflow
#
# Thanks to @VikingPenguinYT
#
# - [Gist](https://gist.github.com/VikingPenguinYT/665769ba03115b1a0888893eaf1d4f13)
# - [You tube video](https://www.youtube.com/watch?v=aa9AC3dTKUQ)
# - [Original paper](https://arxiv.org/pdf/1506.02142.pdf)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.contrib.distributions import Bernoulli


class VariationalDense:
    """Variational Dense Layer Class"""
    def __init__(self, n_in, n_out, model_prob, model_lam):
        self.model_prob = model_prob
        self.model_lam = model_lam
        self.model_bern = Bernoulli(probs=self.model_prob, dtype=tf.float32)
        self.model_M = tf.Variable(tf.truncated_normal([n_in, n_out], stddev=0.01))
        self.model_m = tf.Variable(tf.zeros([n_out]))
        self.model_W = tf.matmul(
            tf.diag(self.model_bern.sample((n_in, ))), self.model_M
        )

    def __call__(self, X, activation=tf.identity):
        output = activation(tf.matmul(X, self.model_W) + self.model_m)
        if self.model_M.shape[1] == 1:
            output = tf.squeeze(output)
        return output

    @property
    def regularization(self):
        return self.model_lam * (
            self.model_prob * tf.reduce_sum(tf.square(self.model_M)) +
            tf.reduce_sum(tf.square(self.model_m))
        )

# Created sample data.
n_samples = 50
X = np.random.normal(size=(n_samples, 1))
y = np.random.normal(np.cos(5.*X) / (np.abs(X) + 1.), 0.1).ravel()
X_pred = np.atleast_2d(np.linspace(-3., 3., num=100)).T
X = np.hstack((X, X**2, X**3))
X_pred = np.hstack((X_pred, X_pred**2, X_pred**3))

# Create the TensorFlow model.
n_feats = X.shape[1]
n_hidden = 100
model_prob = 0.9
model_lam = 1e-2
model_X = tf.placeholder(tf.float32, [None, n_feats])
model_y = tf.placeholder(tf.float32, [None])
model_L_1 = VariationalDense(n_feats, n_hidden, model_prob, model_lam)
model_L_2 = VariationalDense(n_hidden, n_hidden, model_prob, model_lam)
model_L_3 = VariationalDense(n_hidden, 1, model_prob, model_lam)
model_out_1 = model_L_1(model_X, tf.nn.relu)
model_out_2 = model_L_2(model_out_1, tf.nn.relu)
model_pred = model_L_3(model_out_2)
model_sse = tf.reduce_sum(tf.square(model_y - model_pred))
model_mse = model_sse / n_samples
model_loss = (
    # Negative log-likelihood.
    model_sse +
    # Regularization.
    model_L_1.regularization +
    model_L_2.regularization +
    model_L_3.regularization
) / n_samples
train_step = tf.train.AdamOptimizer(1e-3).minimize(model_loss)


with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(10000):
        sess.run(train_step, {model_X: X, model_y: y})
        if i % 100 == 0:
            mse = sess.run(model_mse, {model_X: X, model_y: y})
            print("Iteration {}. Mean squared error: {:.4f}.".format(i, mse))

    # Sample from the posterior.
    n_post = 1000
    Y_post = np.zeros((n_post, X_pred.shape[0]))
    for i in range(n_post):
        Y_post[i] = sess.run(model_pred, {model_X: X_pred})

if True:
    plt.figure(figsize=(8, 6))
    for i in range(n_post):
        plt.plot(X_pred[:, 0], Y_post[i], "b-", alpha=1. / 200)
    plt.plot(X[:, 0], y, "r.")
    plt.grid()
    plt.show()
# Out:
# Iteration 0. Mean squared error: 0.1939.
# Iteration 100. Mean squared error: 0.1236.
# Iteration 200. Mean squared error: 0.0367.
# Iteration 300. Mean squared error: 0.0867.
# Iteration 400. Mean squared error: 0.0524.
# Iteration 500. Mean squared error: 0.0335.
# Iteration 600. Mean squared error: 0.0534.
# Iteration 700. Mean squared error: 0.0177.
# Iteration 800. Mean squared error: 0.0174.
# Iteration 900. Mean squared error: 0.0633.
# Iteration 1000. Mean squared error: 0.0254.
# Iteration 1100. Mean squared error: 0.0159.
# Iteration 1200. Mean squared error: 0.0583.
# Iteration 1300. Mean squared error: 0.0245.
# Iteration 1400. Mean squared error: 0.0135.
# Iteration 1500. Mean squared error: 0.0173.
# Iteration 1600. Mean squared error: 0.0106.
# Iteration 1700. Mean squared error: 0.0332.
# Iteration 1800. Mean squared error: 0.0451.
# Iteration 1900. Mean squared error: 0.0484.
# Iteration 2000. Mean squared error: 0.0129.
# Iteration 2100. Mean squared error: 0.0186.
# Iteration 2200. Mean squared error: 0.0093.
# Iteration 2300. Mean squared error: 0.0340.
# Iteration 2400. Mean squared error: 0.0122.
# Iteration 2500. Mean squared error: 0.0327.
# Iteration 2600. Mean squared error: 0.0152.
# Iteration 2700. Mean squared error: 0.0318.
# Iteration 2800. Mean squared error: 0.0086.
# Iteration 2900. Mean squared error: 0.0133.
# Iteration 3000. Mean squared error: 0.0202.
# Iteration 3100. Mean squared error: 0.0138.
# Iteration 3200. Mean squared error: 0.0379.
# Iteration 3300. Mean squared error: 0.0378.
# Iteration 3400. Mean squared error: 0.0091.
# Iteration 3500. Mean squared error: 0.0114.
# Iteration 3600. Mean squared error: 0.0268.
# Iteration 3700. Mean squared error: 0.0138.
# Iteration 3800. Mean squared error: 0.0094.
# Iteration 3900. Mean squared error: 0.0082.
# Iteration 4000. Mean squared error: 0.0408.
# Iteration 4100. Mean squared error: 0.0086.
# Iteration 4200. Mean squared error: 0.0106.
# Iteration 4300. Mean squared error: 0.0125.
# Iteration 4400. Mean squared error: 0.0086.
# Iteration 4500. Mean squared error: 0.0134.
# Iteration 4600. Mean squared error: 0.0154.
# Iteration 4700. Mean squared error: 0.0171.
# Iteration 4800. Mean squared error: 0.0131.
# Iteration 4900. Mean squared error: 0.0077.
# Iteration 5000. Mean squared error: 0.0176.
# Iteration 5100. Mean squared error: 0.0066.
# Iteration 5200. Mean squared error: 0.0305.
# Iteration 5300. Mean squared error: 0.0316.
# Iteration 5400. Mean squared error: 0.0758.
# Iteration 5500. Mean squared error: 0.0072.
# Iteration 5600. Mean squared error: 0.0099.
# Iteration 5700. Mean squared error: 0.0186.
# Iteration 5800. Mean squared error: 0.0095.
# Iteration 5900. Mean squared error: 0.0640.
# Iteration 6000. Mean squared error: 0.0086.
# Iteration 6100. Mean squared error: 0.0178.
# Iteration 6200. Mean squared error: 0.0229.
# Iteration 6300. Mean squared error: 0.0097.
# Iteration 6400. Mean squared error: 0.0160.
# Iteration 6500. Mean squared error: 0.0216.
# Iteration 6600. Mean squared error: 0.0085.
# Iteration 6700. Mean squared error: 0.0088.
# Iteration 6800. Mean squared error: 0.0110.
# Iteration 6900. Mean squared error: 0.0110.
# Iteration 7000. Mean squared error: 0.0461.
# Iteration 7100. Mean squared error: 0.0102.
# Iteration 7200. Mean squared error: 0.0087.
# Iteration 7300. Mean squared error: 0.0186.
# Iteration 7400. Mean squared error: 0.0128.
# Iteration 7500. Mean squared error: 0.0112.
# Iteration 7600. Mean squared error: 0.0105.
# Iteration 7700. Mean squared error: 0.2540.
# Iteration 7800. Mean squared error: 0.0075.
# Iteration 7900. Mean squared error: 0.0202.
# Iteration 8000. Mean squared error: 0.0066.
# Iteration 8100. Mean squared error: 0.0097.
# Iteration 8200. Mean squared error: 0.0136.
# Iteration 8300. Mean squared error: 0.0085.
# Iteration 8400. Mean squared error: 0.0094.
# Iteration 8500. Mean squared error: 0.0188.
# Iteration 8600. Mean squared error: 0.0069.
# Iteration 8700. Mean squared error: 0.0154.
# Iteration 8800. Mean squared error: 0.0365.
# Iteration 8900. Mean squared error: 0.0316.
# Iteration 9000. Mean squared error: 0.0287.
# Iteration 9100. Mean squared error: 0.0135.
# Iteration 9200. Mean squared error: 0.0093.
# Iteration 9300. Mean squared error: 0.0118.
# Iteration 9400. Mean squared error: 0.0326.
# Iteration 9500. Mean squared error: 0.0082.
# Iteration 9600. Mean squared error: 0.0087.
# Iteration 9700. Mean squared error: 0.0076.
# Iteration 9800. Mean squared error: 0.0086.
# Iteration 9900. Mean squared error: 0.0053.
